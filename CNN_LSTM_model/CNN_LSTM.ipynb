# %%
pip install ta
# Out:
# Requirement already satisfied: ta in /usr/local/lib/python3.10/dist-packages (0.11.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ta) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from ta) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ta) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->ta) (1.16.0)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from sklearn import preprocessing
from keras.layers import Conv1D,Flatten,MaxPooling1D,Bidirectional,LSTM,Dropout,TimeDistributed,MaxPool2D
from keras.layers import Dense,GlobalAveragePooling2D
import matplotlib.pyplot as plt
import os
import pprint
import tensorflow as tf
import yfinance as yf
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

results = []
stocks_to_analyze = ['AAPL', 'BTC-USD', '^GSPC', 'JPM', 'GS', 'TSLA']
for ticker_symbol in stocks_to_analyze:
    stock= yf.download(ticker_symbol, period='max')

    # scaler = preprocessing.MinMaxScaler()
    # scaled_values = scaler.fit_transform(stock.iloc[:,1:4])
    # stock.iloc[:,1:4] = scaled_values
    #
    # y_scaler = preprocessing.MinMaxScaler()
    # scaled_values = y_scaler.fit_transform(np.array(stock.iloc[:,4]).reshape(-1,1))
    # stock.iloc[:,4] = scaled_values
    #
    # scaler = preprocessing.MinMaxScaler()
    # scaled_values = scaler.fit_transform(stock.iloc[:,5:])
    # stock.iloc[:,5:] = scaled_values
    window_size = 50
    week = 7
    X = []
    Y = []

    for i in range(0 , len(stock) - window_size -1 , 1):
        first = stock.iloc[i, 4]
        temp = []
        temp2 = []
        for j in range(window_size):
            temp.append((stock.iloc[i + j, 4] - first) / first)
        # for j in range(week):
        temp2.append((stock.iloc[i +window_size, 4] - first) / first)
        # X.append(np.array(stock.iloc[i:i+window_size,4]).reshape(50,1))
        # Y.append(np.array(stock.iloc[i+window_size,4]).reshape(1,1))
        # print(stock2.iloc[i:i+window_size,4])
        X.append(np.array(temp).reshape(50, 1))
        Y.append(np.array(temp2).reshape(1,1))
    train_X,test_X,train_label,test_label = train_test_split(X, Y, test_size=0.1,shuffle=False)
    len_t = len(train_X)
    # train_X,valid_X,train_label,valid_label = train_test_split(train_X, train_label, test_size=0.2,shuffle=True)

    print(len(train_X))
    print(len(test_X))
    train_X = np.array(train_X)
    test_X = np.array(test_X)
    train_label = np.array(train_label)
    test_label = np.array(test_label)
    # valid_label = np.array(valid_label)
    # valid_X = np.array(valid_X)
    train_X = train_X.reshape(train_X.shape[0],1,50,1)
    test_X = test_X.reshape(test_X.shape[0],1,50,1)
    model = Sequential()
    #add model layers
    model.add(TimeDistributed(Conv1D(128, kernel_size=1, activation='relu', input_shape=(None,50,1))))
    model.add(TimeDistributed(MaxPooling1D(2)))
    model.add(TimeDistributed(Conv1D(256, kernel_size=1, activation='relu')))
    model.add(TimeDistributed(MaxPooling1D(2)))
    model.add(TimeDistributed(Conv1D(512, kernel_size=1, activation='relu')))
    model.add(TimeDistributed(MaxPooling1D(2)))
    model.add(TimeDistributed(Flatten()))
    model.add(Bidirectional(LSTM(200,return_sequences=True)))
    model.add(Dropout(0.25))
    model.add(Bidirectional(LSTM(200,return_sequences=False)))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='linear'))
    model.compile(optimizer='RMSprop', loss='mse')
    model.fit(train_X, train_label, validation_data=(test_X,test_label), epochs=40,batch_size=64,shuffle =False)
    print(model.evaluate(test_X,test_label))
    # model.summary()
    predicted  = model.predict(test_X)
    test_label = (test_label[:,0])
    predicted = np.array(predicted[:,0]).reshape(-1,1)
    for j in range(len_t , len_t + len(test_X)):
        temp =stock.iloc[j,4]
        test_label[j - len_t] = test_label[j - len_t] * temp + temp
        predicted[j - len_t] = predicted[j - len_t] * temp + temp
    plt.plot(test_label, color = 'black', label = ' Stock Price')
    plt.plot(predicted, color = 'green', label = 'Predicted  Stock Price')
    plt.title(' Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel(' Stock Price')
    plt.legend()
    plt.show()
    mse = mean_squared_error(test_label, predicted)
    mae = mean_absolute_error(test_label, predicted)
    r2 = r2_score(test_label, predicted)

    result = {
        'Ticker': ticker_symbol,
        'MSE': mse,
        'MAE': mae,
        'R2 Score': r2
    }
    results.append(result)

for result in results:
    print(f"\nResults for {result['Ticker']}:")
    print(f"MSE: {result['MSE']}")
    print(f"MAE: {result['MAE']}")
    print(f"R2 Score: {result['R2 Score']}")
    # predicted  = model.predict(test_X)
    # test_label[:,0] = y_scaler.inverse_transform(test_label[:,0])
    # predicted = np.array(predicted[:,0]).reshape(-1,1)
    # predicted = y_scaler.inverse_transform(predicted)
    # plt.plot(test_label[:,0], color = 'black', label = ' Stock Price')
    # plt.plot(predicted, color = 'green', label = 'Predicted  Stock Price')
    # plt.title(' Stock Price Prediction')
    # plt.xlabel('Time')
    # plt.ylabel(' Stock Price')
    # plt.legend()
    # plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 9729
# 1082
# Epoch 1/40
# 153/153 [==============================] - 37s 178ms/step - loss: 0.0216 - val_loss: 0.0029
# Epoch 2/40
# 153/153 [==============================] - 25s 164ms/step - loss: 0.0098 - val_loss: 0.0024
# Epoch 3/40
# 153/153 [==============================] - 24s 159ms/step - loss: 0.0080 - val_loss: 0.0028
# Epoch 4/40
# 153/153 [==============================] - 26s 170ms/step - loss: 0.0072 - val_loss: 0.0029
# Epoch 5/40
# 153/153 [==============================] - 25s 164ms/step - loss: 0.0069 - val_loss: 0.0034
# Epoch 6/40
# 153/153 [==============================] - 25s 165ms/step - loss: 0.0064 - val_loss: 0.0022
# Epoch 7/40
# 153/153 [==============================] - 25s 165ms/step - loss: 0.0063 - val_loss: 0.0021
# Epoch 8/40
# 153/153 [==============================] - 24s 158ms/step - loss: 0.0062 - val_loss: 0.0028
# Epoch 9/40
# 153/153 [==============================] - 24s 159ms/step - loss: 0.0060 - val_loss: 0.0024
# Epoch 10/40
# 153/153 [==============================] - 24s 158ms/step - loss: 0.0060 - val_loss: 0.0021
# Epoch 11/40
# 153/153 [==============================] - 25s 164ms/step - loss: 0.0059 - val_loss: 0.0027
# Epoch 12/40
# 153/153 [==============================] - 24s 159ms/step - loss: 0.0058 - val_loss: 0.0024
# Epoch 13/40
# 153/153 [==============================] - 24s 159ms/step - loss: 0.0058 - val_loss: 0.0021
# Epoch 14/40
# 153/153 [==============================] - 25s 164ms/step - loss: 0.0058 - val_loss: 0.0028
# Epoch 15/40
# 153/153 [==============================] - 25s 164ms/step - loss: 0.0057 - val_loss: 0.0025
# Epoch 16/40
# 153/153 [==============================] - 25s 165ms/step - loss: 0.0056 - val_loss: 0.0026
# Epoch 17/40
# 153/153 [==============================] - 24s 156ms/step - loss: 0.0057 - val_loss: 0.0025
# Epoch 18/40
# 153/153 [==============================] - 25s 165ms/step - loss: 0.0056 - val_loss: 0.0023
# Epoch 19/40
# 153/153 [==============================] - 25s 165ms/step - loss: 0.0056 - val_loss: 0.0023
# Epoch 20/40
# 153/153 [==============================] - 25s 164ms/step - loss: 0.0055 - val_loss: 0.0024
# Epoch 21/40
# 153/153 [==============================] - 24s 154ms/step - loss: 0.0054 - val_loss: 0.0032
# Epoch 22/40
# 153/153 [==============================] - 25s 164ms/step - loss: 0.0054 - val_loss: 0.0028
# Epoch 23/40
# 153/153 [==============================] - 25s 165ms/step - loss: 0.0055 - val_loss: 0.0023
# Epoch 24/40
# 153/153 [==============================] - 25s 164ms/step - loss: 0.0054 - val_loss: 0.0031
# Epoch 25/40
# 153/153 [==============================] - 24s 155ms/step - loss: 0.0054 - val_loss: 0.0027
# Epoch 26/40
# 153/153 [==============================] - 25s 160ms/step - loss: 0.0053 - val_loss: 0.0020
# Epoch 27/40
# 153/153 [==============================] - 25s 163ms/step - loss: 0.0053 - val_loss: 0.0024
# Epoch 28/40
# 153/153 [==============================] - 26s 170ms/step - loss: 0.0054 - val_loss: 0.0025
# Epoch 29/40
# 153/153 [==============================] - 26s 169ms/step - loss: 0.0053 - val_loss: 0.0028
# Epoch 30/40
# 153/153 [==============================] - 24s 157ms/step - loss: 0.0053 - val_loss: 0.0020
# Epoch 31/40
# 153/153 [==============================] - 25s 164ms/step - loss: 0.0053 - val_loss: 0.0026
# Epoch 32/40
# 153/153 [==============================] - 25s 164ms/step - loss: 0.0053 - val_loss: 0.0024
# Epoch 33/40
# 153/153 [==============================] - 25s 164ms/step - loss: 0.0052 - val_loss: 0.0027
# Epoch 34/40
# 153/153 [==============================] - 24s 155ms/step - loss: 0.0053 - val_loss: 0.0022
# Epoch 35/40
# 153/153 [==============================] - 25s 164ms/step - loss: 0.0053 - val_loss: 0.0025
# Epoch 36/40
# 153/153 [==============================] - 25s 166ms/step - loss: 0.0053 - val_loss: 0.0022
# Epoch 37/40
# 153/153 [==============================] - 25s 167ms/step - loss: 0.0052 - val_loss: 0.0022
# Epoch 38/40
# 153/153 [==============================] - 24s 154ms/step - loss: 0.0053 - val_loss: 0.0022
# Epoch 39/40
# 153/153 [==============================] - 25s 163ms/step - loss: 0.0052 - val_loss: 0.0023
# Epoch 40/40
# 153/153 [==============================] - 25s 164ms/step - loss: 0.0052 - val_loss: 0.0032
# 34/34 [==============================] - 1s 22ms/step - loss: 0.0032
# 0.0031563483644276857
# 34/34 [==============================] - 2s 21ms/step
# [*********************100%%**********************]  1 of 1 completed
# 3019
# 336
# Epoch 1/40
# 48/48 [==============================] - 23s 223ms/step - loss: 0.1000 - val_loss: 0.0056
# Epoch 2/40
# 48/48 [==============================] - 9s 178ms/step - loss: 0.0349 - val_loss: 0.0045
# Epoch 3/40
# 48/48 [==============================] - 8s 157ms/step - loss: 0.0261 - val_loss: 0.0067
# Epoch 4/40
# 48/48 [==============================] - 9s 189ms/step - loss: 0.0220 - val_loss: 0.0051
# Epoch 5/40
# 48/48 [==============================] - 7s 153ms/step - loss: 0.0194 - val_loss: 0.0062
# Epoch 6/40
# 48/48 [==============================] - 9s 186ms/step - loss: 0.0176 - val_loss: 0.0047
# Epoch 7/40
# 48/48 [==============================] - 8s 168ms/step - loss: 0.0166 - val_loss: 0.0045
# Epoch 8/40
# 48/48 [==============================] - 8s 166ms/step - loss: 0.0168 - val_loss: 0.0042
# Epoch 9/40
# 48/48 [==============================] - 9s 183ms/step - loss: 0.0153 - val_loss: 0.0046
# Epoch 10/40
# 48/48 [==============================] - 7s 152ms/step - loss: 0.0156 - val_loss: 0.0044
# Epoch 11/40
# 48/48 [==============================] - 9s 183ms/step - loss: 0.0157 - val_loss: 0.0042
# Epoch 12/40
# 48/48 [==============================] - 7s 152ms/step - loss: 0.0154 - val_loss: 0.0047
# Epoch 13/40
# 48/48 [==============================] - 8s 174ms/step - loss: 0.0151 - val_loss: 0.0042
# Epoch 14/40
# 48/48 [==============================] - 8s 158ms/step - loss: 0.0147 - val_loss: 0.0043
# Epoch 15/40
# 48/48 [==============================] - 8s 167ms/step - loss: 0.0148 - val_loss: 0.0044
# Epoch 16/40
# 48/48 [==============================] - 9s 183ms/step - loss: 0.0148 - val_loss: 0.0043
# Epoch 17/40
# 48/48 [==============================] - 7s 154ms/step - loss: 0.0149 - val_loss: 0.0042
# Epoch 18/40
# 48/48 [==============================] - 9s 182ms/step - loss: 0.0147 - val_loss: 0.0043
# Epoch 19/40
# 48/48 [==============================] - 7s 142ms/step - loss: 0.0143 - val_loss: 0.0043
# Epoch 20/40
# 48/48 [==============================] - 9s 182ms/step - loss: 0.0148 - val_loss: 0.0043
# Epoch 21/40
# 48/48 [==============================] - 8s 172ms/step - loss: 0.0148 - val_loss: 0.0042
# Epoch 22/40
# 48/48 [==============================] - 8s 166ms/step - loss: 0.0143 - val_loss: 0.0042
# Epoch 23/40
# 48/48 [==============================] - 9s 185ms/step - loss: 0.0143 - val_loss: 0.0043
# Epoch 24/40
# 48/48 [==============================] - 7s 154ms/step - loss: 0.0144 - val_loss: 0.0042
# Epoch 25/40
# 48/48 [==============================] - 9s 185ms/step - loss: 0.0144 - val_loss: 0.0041
# Epoch 26/40
# 48/48 [==============================] - 8s 162ms/step - loss: 0.0142 - val_loss: 0.0042
# Epoch 27/40
# 48/48 [==============================] - 8s 174ms/step - loss: 0.0136 - val_loss: 0.0045
# Epoch 28/40
# 48/48 [==============================] - 9s 182ms/step - loss: 0.0141 - val_loss: 0.0043
# Epoch 29/40
# 48/48 [==============================] - 7s 154ms/step - loss: 0.0141 - val_loss: 0.0042
# Epoch 30/40
# 48/48 [==============================] - 9s 185ms/step - loss: 0.0139 - val_loss: 0.0042
# Epoch 31/40
# 48/48 [==============================] - 7s 153ms/step - loss: 0.0139 - val_loss: 0.0042
# Epoch 32/40
# 48/48 [==============================] - 9s 183ms/step - loss: 0.0140 - val_loss: 0.0042
# Epoch 33/40
# 48/48 [==============================] - 8s 174ms/step - loss: 0.0143 - val_loss: 0.0043
# Epoch 34/40
# 48/48 [==============================] - 8s 160ms/step - loss: 0.0137 - val_loss: 0.0044
# Epoch 35/40
# 48/48 [==============================] - 9s 187ms/step - loss: 0.0137 - val_loss: 0.0044
# Epoch 36/40
# 48/48 [==============================] - 7s 152ms/step - loss: 0.0138 - val_loss: 0.0042
# Epoch 37/40
# 48/48 [==============================] - 9s 184ms/step - loss: 0.0135 - val_loss: 0.0042
# Epoch 38/40
# 48/48 [==============================] - 7s 153ms/step - loss: 0.0136 - val_loss: 0.0043
# Epoch 39/40
# 48/48 [==============================] - 9s 178ms/step - loss: 0.0135 - val_loss: 0.0043
# Epoch 40/40
# 48/48 [==============================] - 9s 182ms/step - loss: 0.0132 - val_loss: 0.0045
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0045
# 0.0045343609526753426
# 11/11 [==============================] - 2s 21ms/step
# [*********************100%%**********************]  1 of 1 completed
# 21665
# 2408
# Epoch 1/40
# 339/339 [==============================] - 68s 175ms/step - loss: 0.0053 - val_loss: 0.0011
# Epoch 2/40
# 339/339 [==============================] - 59s 173ms/step - loss: 0.0018 - val_loss: 8.3809e-04
# Epoch 3/40
# 339/339 [==============================] - 57s 169ms/step - loss: 0.0015 - val_loss: 6.6415e-04
# Epoch 4/40
# 339/339 [==============================] - 56s 166ms/step - loss: 0.0014 - val_loss: 6.7439e-04
# Epoch 5/40
# 339/339 [==============================] - 57s 169ms/step - loss: 0.0013 - val_loss: 6.0868e-04
# Epoch 6/40
# 339/339 [==============================] - 57s 169ms/step - loss: 0.0012 - val_loss: 5.7104e-04
# Epoch 7/40
# 339/339 [==============================] - 58s 170ms/step - loss: 0.0012 - val_loss: 5.2653e-04
# Epoch 8/40
# 339/339 [==============================] - 58s 170ms/step - loss: 0.0012 - val_loss: 5.5077e-04
# Epoch 9/40
# 339/339 [==============================] - 57s 167ms/step - loss: 0.0011 - val_loss: 5.3377e-04
# Epoch 10/40
# 339/339 [==============================] - 57s 168ms/step - loss: 0.0011 - val_loss: 5.4245e-04
# Epoch 11/40
# 339/339 [==============================] - 57s 169ms/step - loss: 0.0011 - val_loss: 5.2334e-04
# Epoch 12/40
# 339/339 [==============================] - 57s 169ms/step - loss: 0.0010 - val_loss: 5.2802e-04
# Epoch 13/40
# 339/339 [==============================] - 57s 169ms/step - loss: 0.0010 - val_loss: 5.3664e-04
# Epoch 14/40
# 339/339 [==============================] - 57s 168ms/step - loss: 9.8771e-04 - val_loss: 5.3471e-04
# Epoch 15/40
# 339/339 [==============================] - 53s 158ms/step - loss: 9.6381e-04 - val_loss: 5.2395e-04
# Epoch 16/40
# 339/339 [==============================] - 57s 168ms/step - loss: 9.6056e-04 - val_loss: 5.2299e-04
# Epoch 17/40
# 339/339 [==============================] - 57s 168ms/step - loss: 9.4244e-04 - val_loss: 5.1347e-04
# Epoch 18/40
# 339/339 [==============================] - 55s 162ms/step - loss: 9.5128e-04 - val_loss: 5.4278e-04
# Epoch 19/40
# 339/339 [==============================] - 57s 169ms/step - loss: 9.4481e-04 - val_loss: 5.1199e-04
# Epoch 20/40
# 339/339 [==============================] - 56s 166ms/step - loss: 9.1375e-04 - val_loss: 5.4047e-04
# Epoch 21/40
# 339/339 [==============================] - 57s 168ms/step - loss: 8.7622e-04 - val_loss: 5.4402e-04
# Epoch 22/40
# 339/339 [==============================] - 57s 168ms/step - loss: 8.7100e-04 - val_loss: 5.3819e-04
# Epoch 23/40
# 339/339 [==============================] - 57s 167ms/step - loss: 8.6140e-04 - val_loss: 5.1385e-04
# Epoch 24/40
# 339/339 [==============================] - 56s 166ms/step - loss: 8.7423e-04 - val_loss: 5.1666e-04
# Epoch 25/40
# 339/339 [==============================] - 54s 158ms/step - loss: 8.5360e-04 - val_loss: 5.2887e-04
# Epoch 26/40
# 339/339 [==============================] - 56s 166ms/step - loss: 8.4299e-04 - val_loss: 5.2334e-04
# Epoch 27/40
# 339/339 [==============================] - 57s 169ms/step - loss: 8.7638e-04 - val_loss: 5.4069e-04
# Epoch 28/40
# 339/339 [==============================] - 57s 167ms/step - loss: 8.7009e-04 - val_loss: 5.2624e-04
# Epoch 29/40
# 339/339 [==============================] - 57s 169ms/step - loss: 8.8316e-04 - val_loss: 5.1921e-04
# Epoch 30/40
# 339/339 [==============================] - 57s 168ms/step - loss: 8.5491e-04 - val_loss: 5.1555e-04
# Epoch 31/40
# 339/339 [==============================] - 57s 167ms/step - loss: 8.4034e-04 - val_loss: 5.2221e-04
# Epoch 32/40
# 339/339 [==============================] - 57s 169ms/step - loss: 8.5294e-04 - val_loss: 5.2954e-04
# Epoch 33/40
# 339/339 [==============================] - 57s 167ms/step - loss: 8.1380e-04 - val_loss: 5.2106e-04
# Epoch 34/40
# 339/339 [==============================] - 57s 167ms/step - loss: 8.2486e-04 - val_loss: 5.1592e-04
# Epoch 35/40
# 339/339 [==============================] - 57s 168ms/step - loss: 8.1406e-04 - val_loss: 5.1778e-04
# Epoch 36/40
# 339/339 [==============================] - 57s 168ms/step - loss: 8.4862e-04 - val_loss: 5.3694e-04
# Epoch 37/40
# 339/339 [==============================] - 56s 167ms/step - loss: 8.5600e-04 - val_loss: 5.2580e-04
# Epoch 38/40
# 339/339 [==============================] - 57s 167ms/step - loss: 8.6007e-04 - val_loss: 5.1508e-04
# Epoch 39/40
# 339/339 [==============================] - 57s 169ms/step - loss: 8.2392e-04 - val_loss: 5.3010e-04
# Epoch 40/40
# 339/339 [==============================] - 56s 167ms/step - loss: 8.4480e-04 - val_loss: 5.2348e-04
# 76/76 [==============================] - 2s 29ms/step - loss: 5.2348e-04
# 0.0005234827985987067
# 76/76 [==============================] - 4s 21ms/step
# [*********************100%%**********************]  1 of 1 completed
# 9899
# 1100
# Epoch 1/40
# 155/155 [==============================] - 38s 182ms/step - loss: 0.0122 - val_loss: 0.0043
# Epoch 2/40
# 155/155 [==============================] - 26s 168ms/step - loss: 0.0052 - val_loss: 0.0033
# Epoch 3/40
# 155/155 [==============================] - 26s 164ms/step - loss: 0.0046 - val_loss: 0.0029
# Epoch 4/40
# 155/155 [==============================] - 26s 170ms/step - loss: 0.0043 - val_loss: 0.0027
# Epoch 5/40
# 155/155 [==============================] - 25s 160ms/step - loss: 0.0040 - val_loss: 0.0025
# Epoch 6/40
# 155/155 [==============================] - 27s 171ms/step - loss: 0.0036 - val_loss: 0.0024
# Epoch 7/40
# 155/155 [==============================] - 26s 170ms/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 8/40
# 155/155 [==============================] - 27s 173ms/step - loss: 0.0033 - val_loss: 0.0022
# Epoch 9/40
# 155/155 [==============================] - 26s 167ms/step - loss: 0.0032 - val_loss: 0.0022
# Epoch 10/40
# 155/155 [==============================] - 26s 165ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 11/40
# 155/155 [==============================] - 27s 171ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 12/40
# 155/155 [==============================] - 26s 170ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 13/40
# 155/155 [==============================] - 27s 171ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 14/40
# 155/155 [==============================] - 26s 170ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 15/40
# 155/155 [==============================] - 26s 169ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 16/40
# 155/155 [==============================] - 26s 167ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 17/40
# 155/155 [==============================] - 25s 163ms/step - loss: 0.0028 - val_loss: 0.0020
# Epoch 18/40
# 155/155 [==============================] - 26s 170ms/step - loss: 0.0028 - val_loss: 0.0020
# Epoch 19/40
# 155/155 [==============================] - 27s 175ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 20/40
# 155/155 [==============================] - 27s 173ms/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 21/40
# 155/155 [==============================] - 26s 170ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 22/40
# 155/155 [==============================] - 27s 174ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 23/40
# 155/155 [==============================] - 27s 173ms/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 24/40
# 155/155 [==============================] - 27s 174ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 25/40
# 155/155 [==============================] - 26s 169ms/step - loss: 0.0026 - val_loss: 0.0019
# Epoch 26/40
# 155/155 [==============================] - 26s 166ms/step - loss: 0.0026 - val_loss: 0.0019
# Epoch 27/40
# 155/155 [==============================] - 26s 168ms/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 28/40
# 155/155 [==============================] - 26s 171ms/step - loss: 0.0026 - val_loss: 0.0019
# Epoch 29/40
# 155/155 [==============================] - 27s 172ms/step - loss: 0.0026 - val_loss: 0.0019
# Epoch 30/40
# 155/155 [==============================] - 27s 173ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 31/40
# 155/155 [==============================] - 27s 172ms/step - loss: 0.0026 - val_loss: 0.0019
# Epoch 32/40
# 155/155 [==============================] - 27s 172ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 33/40
# 155/155 [==============================] - 26s 168ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 34/40
# 155/155 [==============================] - 26s 168ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 35/40
# 155/155 [==============================] - 27s 171ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 36/40
# 155/155 [==============================] - 27s 172ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 37/40
# 155/155 [==============================] - 27s 172ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 38/40
# 155/155 [==============================] - 27s 173ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 39/40
# 155/155 [==============================] - 27s 172ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 40/40
# 155/155 [==============================] - 27s 172ms/step - loss: 0.0025 - val_loss: 0.0018
# 35/35 [==============================] - 1s 22ms/step - loss: 0.0018
# 0.001822368474677205
# 35/35 [==============================] - 2s 22ms/step
# [*********************100%%**********************]  1 of 1 completed
# 5547
# 617
# Epoch 1/40
# 87/87 [==============================] - 27s 210ms/step - loss: 0.0188 - val_loss: 0.0040
# Epoch 2/40
# 87/87 [==============================] - 15s 170ms/step - loss: 0.0065 - val_loss: 0.0038
# Epoch 3/40
# 87/87 [==============================] - 15s 170ms/step - loss: 0.0052 - val_loss: 0.0037
# Epoch 4/40
# 87/87 [==============================] - 15s 170ms/step - loss: 0.0045 - val_loss: 0.0035
# Epoch 5/40
# 87/87 [==============================] - 15s 169ms/step - loss: 0.0040 - val_loss: 0.0032
# Epoch 6/40
# 87/87 [==============================] - 15s 170ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 7/40
# 87/87 [==============================] - 15s 168ms/step - loss: 0.0036 - val_loss: 0.0030
# Epoch 8/40
# 87/87 [==============================] - 15s 170ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 9/40
# 87/87 [==============================] - 15s 169ms/step - loss: 0.0033 - val_loss: 0.0029
# Epoch 10/40
# 87/87 [==============================] - 15s 170ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 11/40
# 87/87 [==============================] - 15s 169ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 12/40
# 87/87 [==============================] - 15s 168ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 13/40
# 87/87 [==============================] - 15s 169ms/step - loss: 0.0031 - val_loss: 0.0021
# Epoch 14/40
# 87/87 [==============================] - 15s 168ms/step - loss: 0.0029 - val_loss: 0.0019
# Epoch 15/40
# 87/87 [==============================] - 15s 168ms/step - loss: 0.0030 - val_loss: 0.0022
# Epoch 16/40
# 87/87 [==============================] - 15s 168ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 17/40
# 87/87 [==============================] - 15s 168ms/step - loss: 0.0029 - val_loss: 0.0019
# Epoch 18/40
# 87/87 [==============================] - 15s 170ms/step - loss: 0.0029 - val_loss: 0.0019
# Epoch 19/40
# 87/87 [==============================] - 15s 167ms/step - loss: 0.0029 - val_loss: 0.0018
# Epoch 20/40
# 87/87 [==============================] - 15s 173ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 21/40
# 87/87 [==============================] - 15s 176ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 22/40
# 87/87 [==============================] - 15s 175ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 23/40
# 87/87 [==============================] - 15s 171ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 24/40
# 87/87 [==============================] - 15s 170ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 25/40
# 87/87 [==============================] - 15s 170ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 26/40
# 87/87 [==============================] - 15s 175ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 27/40
# 87/87 [==============================] - 15s 170ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 28/40
# 87/87 [==============================] - 15s 171ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 29/40
# 87/87 [==============================] - 15s 168ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 30/40
# 87/87 [==============================] - 15s 170ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 31/40
# 87/87 [==============================] - 15s 170ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 32/40
# 87/87 [==============================] - 15s 170ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 33/40
# 87/87 [==============================] - 15s 173ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 34/40
# 87/87 [==============================] - 15s 170ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 35/40
# 87/87 [==============================] - 14s 159ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 36/40
# 87/87 [==============================] - 15s 170ms/step - loss: 0.0026 - val_loss: 0.0017
# Epoch 37/40
# 87/87 [==============================] - 15s 170ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 38/40
# 87/87 [==============================] - 15s 170ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 39/40
# 87/87 [==============================] - 15s 169ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 40/40
# 87/87 [==============================] - 15s 169ms/step - loss: 0.0026 - val_loss: 0.0016
# 20/20 [==============================] - 0s 22ms/step - loss: 0.0016
# 0.0016408455558121204
# 20/20 [==============================] - 2s 22ms/step
# [*********************100%%**********************]  1 of 1 completed
# 3022
# 336
# Epoch 1/40
# 48/48 [==============================] - 24s 228ms/step - loss: 0.0775 - val_loss: 0.0236
# Epoch 2/40
# 48/48 [==============================] - 8s 175ms/step - loss: 0.0354 - val_loss: 0.0225
# Epoch 3/40
# 48/48 [==============================] - 8s 174ms/step - loss: 0.0276 - val_loss: 0.0198
# Epoch 4/40
# 48/48 [==============================] - 9s 190ms/step - loss: 0.0229 - val_loss: 0.0170
# Epoch 5/40
# 48/48 [==============================] - 8s 158ms/step - loss: 0.0205 - val_loss: 0.0165
# Epoch 6/40
# 48/48 [==============================] - 9s 182ms/step - loss: 0.0196 - val_loss: 0.0146
# Epoch 7/40
# 48/48 [==============================] - 8s 167ms/step - loss: 0.0183 - val_loss: 0.0140
# Epoch 8/40
# 48/48 [==============================] - 8s 175ms/step - loss: 0.0177 - val_loss: 0.0134
# Epoch 9/40
# 48/48 [==============================] - 9s 189ms/step - loss: 0.0172 - val_loss: 0.0125
# Epoch 10/40
# 48/48 [==============================] - 8s 158ms/step - loss: 0.0171 - val_loss: 0.0121
# Epoch 11/40
# 48/48 [==============================] - 9s 186ms/step - loss: 0.0168 - val_loss: 0.0118
# Epoch 12/40
# 48/48 [==============================] - 8s 162ms/step - loss: 0.0166 - val_loss: 0.0113
# Epoch 13/40
# 48/48 [==============================] - 9s 179ms/step - loss: 0.0165 - val_loss: 0.0114
# Epoch 14/40
# 48/48 [==============================] - 9s 188ms/step - loss: 0.0157 - val_loss: 0.0107
# Epoch 15/40
# 48/48 [==============================] - 8s 159ms/step - loss: 0.0159 - val_loss: 0.0105
# Epoch 16/40
# 48/48 [==============================] - 9s 187ms/step - loss: 0.0157 - val_loss: 0.0102
# Epoch 17/40
# 48/48 [==============================] - 7s 156ms/step - loss: 0.0159 - val_loss: 0.0103
# Epoch 18/40
# 48/48 [==============================] - 9s 185ms/step - loss: 0.0152 - val_loss: 0.0103
# Epoch 19/40
# 48/48 [==============================] - 9s 184ms/step - loss: 0.0153 - val_loss: 0.0099
# Epoch 20/40
# 48/48 [==============================] - 8s 157ms/step - loss: 0.0146 - val_loss: 0.0099
# Epoch 21/40
# 48/48 [==============================] - 9s 188ms/step - loss: 0.0146 - val_loss: 0.0098
# Epoch 22/40
# 48/48 [==============================] - 7s 156ms/step - loss: 0.0147 - val_loss: 0.0100
# Epoch 23/40
# 48/48 [==============================] - 9s 186ms/step - loss: 0.0147 - val_loss: 0.0098
# Epoch 24/40
# 48/48 [==============================] - 8s 173ms/step - loss: 0.0141 - val_loss: 0.0095
# Epoch 25/40
# 48/48 [==============================] - 8s 167ms/step - loss: 0.0148 - val_loss: 0.0095
# Epoch 26/40
# 48/48 [==============================] - 9s 187ms/step - loss: 0.0139 - val_loss: 0.0097
# Epoch 27/40
# 48/48 [==============================] - 8s 163ms/step - loss: 0.0143 - val_loss: 0.0096
# Epoch 28/40
# 48/48 [==============================] - 9s 189ms/step - loss: 0.0143 - val_loss: 0.0096
# Epoch 29/40
# 48/48 [==============================] - 8s 172ms/step - loss: 0.0145 - val_loss: 0.0097
# Epoch 30/40
# 48/48 [==============================] - 8s 168ms/step - loss: 0.0136 - val_loss: 0.0097
# Epoch 31/40
# 48/48 [==============================] - 9s 188ms/step - loss: 0.0141 - val_loss: 0.0099
# Epoch 32/40
# 48/48 [==============================] - 8s 158ms/step - loss: 0.0137 - val_loss: 0.0096
# Epoch 33/40
# 48/48 [==============================] - 9s 189ms/step - loss: 0.0141 - val_loss: 0.0094
# Epoch 34/40
# 48/48 [==============================] - 8s 166ms/step - loss: 0.0142 - val_loss: 0.0094
# Epoch 35/40
# 48/48 [==============================] - 8s 175ms/step - loss: 0.0138 - val_loss: 0.0093
# Epoch 36/40
# 48/48 [==============================] - 9s 187ms/step - loss: 0.0139 - val_loss: 0.0095
# Epoch 37/40
# 48/48 [==============================] - 8s 156ms/step - loss: 0.0129 - val_loss: 0.0093
# Epoch 38/40
# 48/48 [==============================] - 9s 189ms/step - loss: 0.0136 - val_loss: 0.0095
# Epoch 39/40
# 48/48 [==============================] - 8s 160ms/step - loss: 0.0131 - val_loss: 0.0094
# Epoch 40/40
# 48/48 [==============================] - 9s 183ms/step - loss: 0.0133 - val_loss: 0.0094
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0094
# 0.009410848841071129
# 11/11 [==============================] - 2s 22ms/step
# Results for AAPL:
# MSE: 42.69958677071878
# MAE: 5.371718094661804
# R2 Score: 0.9700769260188764
#
# Results for BTC-USD:
# MSE: 2997972.5234934716
# MAE: 1303.271740141369
# R2 Score: 0.9165436396596135
#
# Results for ^GSPC:
# MSE: 5923.246206010924
# MAE: 49.911430941863706
# R2 Score: 0.9925179208756475
#
# Results for JPM:
# MSE: 25.548638519693686
# MAE: 3.8516249292547053
# R2 Score: 0.9502026225030213
#
# Results for GS:
# MSE: 180.60886196035295
# MAE: 10.539019864420837
# R2 Score: 0.7909083089803858
#
# Results for TSLA:
# MSE: 386.22431389331905
# MAE: 16.187827973138717
# R2 Score: 0.8000945596489765
